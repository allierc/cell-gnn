# %% [markdown]
# # Presentation Videos v1 — Pairwise + Gaussian Fields (Cases 1–3)
#
# **Case 1:** Pairwise force only (GNN, position loss)
# **Case 2:** + Static Gaussian field — {big, small} × {GNN only, GNN+SIREN}
# **Case 3:** + Moving Gaussian field — {big, small} × {GNN only, GNN+SIREN}
#
# Diffusion field (Case 4) is in `generate_videos_v2.ipynb`.

# %%
import sys, os, re

PROJ = '/groups/jingyiliu/home/liuj4/cell-gnn'
sys.path.insert(0, PROJ)
os.chdir(PROJ)

import torch
import numpy as np
import zarr
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from pathlib import Path
import subprocess, shutil

from cell_gnn.config import CellGNNConfig
from cell_gnn.utils import to_numpy
from cell_gnn.models.Siren_Network import Siren
from cell_gnn.models.MLP import MLP
from cell_gnn.graph_utils import scatter_aggregate
from cell_gnn.plot import build_edge_features, _batched_mlp_eval

PROJ = Path(PROJ)
VID_DIR = PROJ / 'presentation' / 'videos'
VID_DIR.mkdir(parents=True, exist_ok=True)

def load_config(n):
    return CellGNNConfig.from_yaml(str(PROJ / 'config' / 'misc' / f'{n}.yaml'))
def load_pos(d):
    return np.array(zarr.open(str(PROJ/'graphs_data'/'misc'/d/'x_list_0'/'pos.zarr'),'r')[:])
def load_field(d):
    return np.array(zarr.open(str(PROJ/'graphs_data'/'misc'/d/'x_list_0'/'field.zarr'),'r')[:])
def load_vel(d):
    return np.array(zarr.open(str(PROJ/'graphs_data'/'misc'/d/'x_list_0'/'vel.zarr'),'r')[:])

def load_checkpoint(config_name):
    md = PROJ / 'log' / 'misc' / config_name / 'models'
    ckpts = sorted(md.glob('best_model_with_0_graphs_0_*.pt'),
                   key=lambda p: int(p.stem.split('_')[-1]))
    if not ckpts:
        ckpts = list(md.glob('best_model_with_0_graphs_0.pt'))
    raw = torch.load(ckpts[-1], map_location='cpu', weights_only=False)
    state = raw.get('model_state_dict', raw) if isinstance(raw, dict) else raw
    return {k.replace('_orig_mod.', ''): v for k, v in state.items()}

def all_checkpoints(config_name):
    md = PROJ / 'log' / 'misc' / config_name / 'models'
    pat = re.compile(r'best_model_with_0_graphs_(\d+)_(\d+)\.pt$')
    results = []
    for p in md.glob('best_model_with_0_graphs_*_*.pt'):
        m = pat.search(str(p))
        if m:
            epoch, iteration = int(m.group(1)), int(m.group(2))
            results.append((epoch, iteration, p))
    results.sort(key=lambda x: (x[0], x[1]))
    return [(f'Ep {ep} / {it:,}', p) for ep, it, p in results]

def get_particle_radius(config_name):
    cfg = load_config(config_name)
    r0 = cfg.simulation.cell_params[0][1]
    return r0 * 0.3

def data_to_scatter_size(radius, fig_width_inches, dpi, data_range=1.0, axis_fraction=0.65):
    fig_width_pts = fig_width_inches * 72
    axis_width_pts = fig_width_pts * axis_fraction
    pts_per_data = axis_width_pts / data_range
    radius_pts = radius * pts_per_data
    return np.pi * radius_pts ** 2

def frames_to_mp4(frame_dir, output_path, fps=30):
    subprocess.run(['ffmpeg','-y','-loglevel','error','-framerate',str(fps),
        '-i',f'{frame_dir}/frame_%06d.png',
        '-vf','scale=trunc(iw/2)*2:trunc(ih/2)*2',
        '-c:v','libx264','-crf','23','-pix_fmt','yuv420p',
        str(output_path)], check=True)
    print(f'  -> {output_path.name}')

def clean_3d_ax(ax):
    ax.grid(False)
    ax.xaxis.pane.fill = False
    ax.yaxis.pane.fill = False
    ax.zaxis.pane.fill = False
    ax.xaxis.pane.set_edgecolor('k')
    ax.yaxis.pane.set_edgecolor('k')
    ax.zaxis.pane.set_edgecolor('k')
    ax.set_xlim(0, 1); ax.set_ylim(0, 1); ax.set_zlim(0, 1)
    ax.set_box_aspect([1, 1, 1])
    ax.set_xlabel('x'); ax.set_ylabel('y'); ax.set_zlabel('z')

print('Setup done.')
# Out:
# Setup done.

# %% [markdown]
# ---
# ## Video functions

# %%
def make_simulation_3d(dataset_name, config_name, title, output_name,
                       frame_step=50, fps=30, max_frames=160, has_field=True):
    """3D rotating scatter of GT cell positions with physically correct particle size."""
    pos = load_pos(dataset_name)
    field = load_field(dataset_name)
    T = pos.shape[0]
    idxs = np.arange(0, min(T, max_frames * frame_step), frame_step)
    
    particle_r = get_particle_radius(config_name)
    fig_w = 7
    dpi = 120
    s = data_to_scatter_size(particle_r, fig_w, dpi)
    print(f'  particle radius = {particle_r}, scatter s = {s:.1f}')
    
    f_all = field[idxs, :, 0]
    nz = f_all[f_all != 0]
    use_field = has_field and len(nz) > 0
    if use_field:
        vmin, vmax = np.percentile(nz, [2, 98])
        if vmin == vmax: vmin, vmax = -1, 1
    
    tmp = VID_DIR / f'_tmp_{output_name}'; tmp.mkdir(exist_ok=True)
    fig = plt.figure(figsize=(fig_w, fig_w))
    ax = fig.add_subplot(111, projection='3d')
    
    for i, fi in enumerate(idxs):
        ax.clear()
        p = pos[fi]
        if use_field:
            f = field[fi, :, 0]
            ax.scatter(p[:,0], p[:,1], p[:,2], c=f, s=s, alpha=0.7,
                       cmap='coolwarm', vmin=vmin, vmax=vmax,
                       edgecolors='none', depthshade=True)
        else:
            ax.scatter(p[:,0], p[:,1], p[:,2], s=s, alpha=0.7,
                       c='#1f77b4', edgecolors='none', depthshade=True)
        clean_3d_ax(ax)
        ax.set_title(f'{title}\n$t = {fi*0.002:.2f}$', fontsize=12)
        ax.view_init(elev=25, azim=30 + i * 0.5)
        fig.savefig(tmp / f'frame_{i:06d}.png', dpi=dpi, bbox_inches='tight')
        if i % 50 == 0: print(f'  {i}/{len(idxs)}')
    plt.close(fig)
    frames_to_mp4(tmp, VID_DIR / f'{output_name}.mp4', fps)
    shutil.rmtree(tmp)

# %%
def make_reconstruction_3d(dataset_name, config_name, title, output_name,
                           frame_step=50, fps=20, max_frames=160, n_rollout=10):
    """Side-by-side 3D: GT positions (left) vs model rollout positions (right)."""
    pos_all = load_pos(dataset_name)
    T, N, _ = pos_all.shape
    dt = 0.002
    
    cfg = load_config(config_name)
    dim = cfg.simulation.dimension
    emb_dim = cfg.graph_model.embedding_dim
    max_radius = cfg.simulation.max_radius
    isz = dim + 1 + emb_dim
    
    particle_r = get_particle_radius(config_name)
    fig_w = 14
    dpi = 120
    s = data_to_scatter_size(particle_r, fig_w / 2, dpi)
    print(f'  particle radius = {particle_r}, scatter s = {s:.1f}')
    
    state = load_checkpoint(config_name)
    lin_edge = MLP(input_size=isz, output_size=cfg.graph_model.output_size,
                   nlayers=cfg.graph_model.n_layers, hidden_size=cfg.graph_model.hidden_dim,
                   device='cpu')
    es = {k.replace('lin_edge.',''):v for k,v in state.items() if k.startswith('lin_edge.')}
    lin_edge.load_state_dict(es); lin_edge.eval()
    med_emb = state['a'][0].median(dim=0).values if 'a' in state else torch.zeros(emb_dim)
    
    def predict_vel(pos_t):
        N = pos_t.shape[0]
        dist = torch.cdist(pos_t, pos_t)
        pred = torch.zeros(N, 3)
        for ci in range(N):
            nbrs = (dist[ci] < max_radius) & (dist[ci] > 0)
            if not nbrs.any(): continue
            dp = (pos_t[nbrs] - pos_t[ci]) / max_radius
            r = dist[ci, nbrs].unsqueeze(1) / max_radius
            emb = med_emb.unsqueeze(0).expand(dp.shape[0], -1)
            inp = torch.cat([dp, r, emb], dim=-1)
            pred[ci] = lin_edge(inp).sum(dim=0)
        return pred
    
    idxs = np.arange(0, min(T - n_rollout, max_frames * frame_step), frame_step)
    tmp = VID_DIR / f'_tmp_{output_name}'; tmp.mkdir(exist_ok=True)
    fig = plt.figure(figsize=(fig_w, 6))
    ax1 = fig.add_subplot(121, projection='3d')
    ax2 = fig.add_subplot(122, projection='3d')
    
    for i, fi in enumerate(idxs):
        with torch.no_grad():
            cur = torch.tensor(pos_all[fi], dtype=torch.float32)
            for _ in range(n_rollout):
                vel = predict_vel(cur)
                cur = (cur + vel * dt) % 1.0
        pred_pos = cur.numpy()
        gt_pos = pos_all[fi + n_rollout]
        
        ax1.clear(); ax2.clear()
        
        ax1.scatter(gt_pos[:,0], gt_pos[:,1], gt_pos[:,2],
                   s=s, alpha=0.7, c='#1f77b4', edgecolors='none', depthshade=True)
        clean_3d_ax(ax1)
        ax1.set_title('Ground Truth', fontsize=12)
        ax1.view_init(elev=25, azim=30 + i*0.5)
        
        ax2.scatter(pred_pos[:,0], pred_pos[:,1], pred_pos[:,2],
                   s=s, alpha=0.7, c='#d62728', edgecolors='none', depthshade=True)
        clean_3d_ax(ax2)
        ax2.set_title(f'Reconstructed ({n_rollout}-step rollout)', fontsize=12)
        ax2.view_init(elev=25, azim=30 + i*0.5)
        
        fig.suptitle(f'{title}   $t = {fi*dt:.2f}$', fontsize=13)
        fig.tight_layout()
        fig.savefig(tmp / f'frame_{i:06d}.png', dpi=dpi, bbox_inches='tight')
        if i % 10 == 0: print(f'  {i}/{len(idxs)}')
    
    plt.close(fig)
    frames_to_mp4(tmp, VID_DIR / f'{output_name}.mp4', fps)
    shutil.rmtree(tmp)

# %%
def make_force_learning_video(config_name, output_name, fps=8):
    """Stitch existing MLP1 PNGs from log dir into a video."""
    mlp1_dir = PROJ / 'log' / 'misc' / config_name / 'tmp_training' / 'function' / 'MLP1'
    if not mlp1_dir.exists():
        print(f'  No MLP1 dir: {mlp1_dir}')
        return
    
    pat = re.compile(r'function_(\d+)_(\d+)\.png$')
    pngs = []
    for p in mlp1_dir.glob('function_*.png'):
        m = pat.search(p.name)
        if m:
            pngs.append((int(m.group(1)), int(m.group(2)), p))
    pngs.sort(key=lambda x: (x[0], x[1]))
    
    if not pngs:
        print(f'  No MLP1 PNGs found'); return
    print(f'  Found {len(pngs)} MLP1 plots')
    
    target_frames = 30
    pngs = pngs[::max(1, len(pngs) // target_frames)]
    print(f'  Using {len(pngs)} frames')
    
    tmp = VID_DIR / f'_tmp_{output_name}'; tmp.mkdir(exist_ok=True)
    for i, (ep, it, src) in enumerate(pngs):
        dst = tmp / f'frame_{i:06d}.png'
        shutil.copy2(src, dst)
    
    frames_to_mp4(tmp, VID_DIR / f'{output_name}.mp4', fps)
    shutil.rmtree(tmp)

# %%
def make_loss_curve(config_name, output_name):
    """Save a static loss curve PNG (not a video). Uses loss.pt from log dir."""
    log_dir = PROJ / 'log' / 'misc' / config_name
    loss_path = log_dir / 'loss.pt'
    if not loss_path.exists():
        print(f'  No loss.pt in {log_dir}')
        return
    
    loss_data = torch.load(loss_path, map_location='cpu', weights_only=False)
    
    if isinstance(loss_data, list):
        loss_vals = np.array(loss_data)
    elif isinstance(loss_data, dict):
        # Try to get separate components
        loss_vals = None
        for key in ['loss', 'train_loss', 'total']:
            if key in loss_data:
                loss_vals = np.array(loss_data[key])
                break
        if loss_vals is None:
            loss_vals = np.array(list(loss_data.values())[0])
    else:
        loss_vals = to_numpy(torch.tensor(loss_data))
    
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    ax.plot(np.arange(len(loss_vals)), loss_vals, 'b-', lw=2)
    ax.set_xlabel('Epoch', fontsize=12)
    ax.set_ylabel('Loss', fontsize=12)
    ax.set_title(f'Training Loss — {config_name}', fontsize=11)
    ax.grid(True, alpha=0.3)
    if len(loss_vals) > 2 and loss_vals.max() / max(loss_vals.min(), 1e-10) > 10:
        ax.set_yscale('log')
    fig.tight_layout()
    out_path = VID_DIR / f'{output_name}.png'
    fig.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.close(fig)
    print(f'  -> {out_path.name}')

# %%
def make_field_learning_video(config_name, output_name, resolution=60,
                               frame_step=50, fps=30, max_frames=160):
    """Left: top-down learned field z-slice. Right: 3D particles colored by learned c."""
    cfg = load_config(config_name)
    dim = cfg.simulation.dimension
    n_frames = cfg.simulation.n_frames
    omega = getattr(cfg.graph_model, 'omega_field', 30.0)
    
    particle_r = get_particle_radius(config_name)
    fig_w = 13
    dpi = 120
    s = data_to_scatter_size(particle_r, fig_w / 2, dpi)
    
    state = load_checkpoint(config_name)
    sk = [k for k in state if k.startswith('siren_field.net.')]
    if not sk: print(f'  No siren_field in {config_name}'); return
    nm = len(set(k.split('.')[2] for k in sk))
    hd = state['siren_field.net.0.linear.weight'].shape[0]
    
    last_layer = max(int(k.split('.')[2]) for k in sk)
    out_features = state[f'siren_field.net.{last_layer}.bias'].shape[0]
    
    siren = Siren(in_features=dim+1, out_features=out_features, hidden_features=hd,
                  hidden_layers=max(nm-2,0), outermost_linear=True,
                  first_omega_0=omega, hidden_omega_0=omega)
    ss = {k.replace('siren_field.',''):v for k,v in state.items() if k.startswith('siren_field.')}
    siren.load_state_dict(ss); siren.eval()
    
    c1d = torch.linspace(0,1,resolution)
    gy,gx = torch.meshgrid(c1d,c1d,indexing='ij')
    g2d = torch.stack([gx.reshape(-1),gy.reshape(-1)],dim=1)
    g3d = torch.cat([g2d, 0.5*torch.ones(resolution**2,1)], dim=1)
    
    pos_all = load_pos(cfg.dataset); T = pos_all.shape[0]
    
    vs = []
    with torch.no_grad():
        for tf in np.linspace(0.01,0.99,10):
            out = siren(torch.cat([g3d,tf*torch.ones(resolution**2,1)],1))
            vs.append(out[:,0].numpy())
    av = np.concatenate(vs)
    vmin,vmax = np.percentile(av,[2,98])
    
    tmp = VID_DIR/f'_tmp_{output_name}'; tmp.mkdir(exist_ok=True)
    fig = plt.figure(figsize=(fig_w, 5.5))
    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122, projection='3d')
    fc = 0
    
    for fi in range(0, min(T, max_frames*frame_step), frame_step):
        tf = fi / n_frames
        with torch.no_grad():
            out = siren(torch.cat([g3d,tf*torch.ones(resolution**2,1)],1))
            c = out[:,0].reshape(resolution,resolution).numpy()
        
        ax1.clear(); ax2.clear()
        ax1.imshow(c, origin='lower', extent=[0,1,0,1], cmap='viridis', vmin=vmin, vmax=vmax)
        ax1.set_title('Learned $c(\\mathbf{x},t)$  ($z\\!=\\!0.5$)', fontsize=12)
        ax1.set_xlabel('x'); ax1.set_ylabel('y')
        
        pn = pos_all[min(fi,T-1)]
        with torch.no_grad():
            pt = torch.tensor(pn, dtype=torch.float32)
            out_cell = siren(torch.cat([pt, tf*torch.ones(pt.shape[0],1)],1))
            cc = out_cell[:,0].numpy()
        ax2.scatter(pn[:,0],pn[:,1],pn[:,2], c=cc, s=s, alpha=0.7,
                   cmap='viridis', vmin=vmin, vmax=vmax, edgecolors='none', depthshade=True)
        clean_3d_ax(ax2)
        ax2.set_title('3D cells (color = learned $c$)', fontsize=12)
        ax2.view_init(elev=25, azim=30+fc*0.5)
        
        fig.suptitle(f'Learned Field   $t={fi*0.002:.2f}$', fontsize=13)
        fig.tight_layout()
        fig.savefig(tmp/f'frame_{fc:06d}.png', dpi=dpi, bbox_inches='tight')
        fc += 1
        if fc%50==0: print(f'  {fc}')
    
    plt.close(fig)
    frames_to_mp4(tmp, VID_DIR/f'{output_name}.mp4', fps)
    shutil.rmtree(tmp)

# %% [markdown]
# ---
# ## Config registry
#
# | Case | Sub | Field | Arch | Config name | Dataset name |
# |------|-----|-------|------|-------------|--------------|
# | 1 | — | none | GNN | `dicty_spring_force_rk4` | same |
# | 2 | a | static big (σ=0.15) | GNN | `..._static_field_big_gnn` | same |
# | 2 | b | static big (σ=0.15) | GNN+SIREN | `..._static_field_big_siren` | same |
# | 2 | c | static small (σ=0.05, 8 src) | GNN | `..._static_field_small_gnn` | same |
# | 2 | d | static small (σ=0.05, 8 src) | GNN+SIREN | `..._static_field_small_siren` | same |
# | 3 | a | moving big (σ=0.15) | GNN | `..._dynamic_field` | same |
# | 3 | b | moving big (σ=0.15) | GNN+SIREN | `..._dynamic_field_siren` | same |
# | 3 | c | moving small (σ=0.05, 8 src) | GNN | `..._dynamic_field_small_gnn` | same |
# | 3 | d | moving small (σ=0.05, 8 src) | GNN+SIREN | `..._dynamic_field_siren_v9` | same |
#
# All field params (centers, sigma, mu_chem) are consistent between static/moving pairs — only velocity differs.

# %%
def data_exists(dataset_name):
    return (PROJ/'graphs_data'/'misc'/dataset_name/'x_list_0'/'pos.zarr').exists()

def model_exists(config_name):
    return len(all_checkpoints(config_name)) > 0

def has_siren(config_name):
    cfg = load_config(config_name)
    return 'siren' in cfg.graph_model.cell_model_name

def run_subcase(config_name, dataset_name, label, prefix, has_field=True):
    """Run all videos for one sub-case: simulation, force learning, field learning (if SIREN), reconstruction."""
    print(f'\n{"="*60}')
    print(f'{label}')
    print(f'  config:  {config_name}')
    print(f'  dataset: {dataset_name}')
    print(f'{"="*60}')
    
    if not data_exists(dataset_name):
        print(f'  ** Data not generated yet — skipping')
        return
    
    print(f'\n--- Simulation ---')
    make_simulation_3d(dataset_name, config_name, label, f'{prefix}_sim', has_field=has_field)
    
    if not model_exists(config_name):
        print(f'  ** Model not trained yet — skipping force/field/recon')
        return
    
    print(f'\n--- Force learning ---')
    make_force_learning_video(config_name, f'{prefix}_force')
    
    if has_siren(config_name):
        print(f'\n--- Field learning ---')
        make_field_learning_video(config_name, f'{prefix}_field')
    
    print(f'\n--- Reconstruction ---')
    make_reconstruction_3d(dataset_name, config_name, label, f'{prefix}_recon', n_rollout=5)
    
    print(f'\nDone: {label}\n')

# %% [markdown]
# ---
# ## Case 1: Pairwise force only (GNN, no field)

# %%
run_subcase(
    config_name='dicty_spring_force_rk4',
    dataset_name='dicty_spring_force_rk4',
    label='Case 1: Pairwise Only',
    prefix='case1',
    has_field=False,
)
# Out:
# ============================================================
# Case 1: Pairwise Only
#   config:  dicty_spring_force_rk4
#   dataset: dicty_spring_force_rk4
# ============================================================
#
# --- Simulation ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   50/160
#   100/160
#   150/160
#   -> case1_sim.mp4
#
# --- Force learning ---
#   Found 80 MLP1 plots
#   Using 40 frames
#   -> case1_force.mp4
#
# --- Reconstruction ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   10/160
#   20/160
#   30/160
#   40/160
#   50/160
#   60/160
#   70/160
#   80/160
#   90/160
#   100/160
#   110/160
#   120/160
#   130/160
#   140/160
#   150/160
#   -> case1_recon.mp4
#
# Done: Case 1: Pairwise Only

# %% [markdown]
# ---
# ## Case 2: Static Gaussian field
#
# ### 2a: `dicty_case2a_rk4_static_single_gaussian_gnn` (GNN only)

# %%
CFG_2A = 'dicty_case2a_rk4_static_single_gaussian_gnn'
DAT_2A = 'dicty_case2a_rk4_static_single_gaussian_gnn'

run_subcase(
    config_name=CFG_2A,
    dataset_name=DAT_2A,
    label='Case 2a: Static Single Gaussian — GNN only',
    prefix='case2a',
)

print('\n--- Loss curve ---')
make_loss_curve(CFG_2A, 'case2a_loss')
# Out:
# ============================================================
# Case 2a: Static Single Gaussian — GNN only
#   config:  dicty_case2a_rk4_static_single_gaussian_gnn
#   dataset: dicty_case2a_rk4_static_single_gaussian_gnn
# ============================================================
#   ** Data not generated yet — skipping
#
# --- Loss curve ---
#   No loss.pt in /groups/jingyiliu/home/liuj4/cell-gnn/log/misc/dicty_case2a_rk4_static_single_gaussian_gnn

# %% [markdown]
# ### 2b: `dicty_case2a_rk4_static_single_gaussian_gnn_siren` (GNN + SIREN)

# %%
CFG_2B = 'dicty_case2a_rk4_static_single_gaussian_gnn_siren'
DAT_2B = 'dicty_case2a_rk4_static_single_gaussian_gnn_siren'

run_subcase(
    config_name=CFG_2B,
    dataset_name=DAT_2B,
    label='Case 2b: Static Single Gaussian — GNN + SIREN',
    prefix='case2b',
)

print('\n--- Loss curve ---')
make_loss_curve(CFG_2B, 'case2b_loss')
# Out:
# ============================================================
# Case 2b: Static Single Gaussian — GNN + SIREN
#   config:  dicty_case2a_rk4_static_single_gaussian_gnn_siren
#   dataset: dicty_case2a_rk4_static_single_gaussian_gnn_siren
# ============================================================
#
# --- Simulation ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   50/160
#   100/160
#   150/160
#   -> case2b_sim.mp4
#
# --- Force learning ---
#   Found 160 MLP1 plots
#   Using 32 frames
#   -> case2b_force.mp4
#
# --- Field learning ---
#   50
#   100
#   150
#   -> case2b_field.mp4
#
# --- Reconstruction ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   10/160
#   20/160
#   30/160
#   40/160
#   50/160
#   60/160
#   70/160
#   80/160
#   90/160
#   100/160
#   110/160
#   120/160
#   130/160
#   140/160
#   150/160
#   -> case2b_recon.mp4
#
# Done: Case 2b: Static Single Gaussian — GNN + SIREN
#
#
# --- Loss curve ---
#   -> case2b_loss.png

# %% [markdown]
# ### 2c: Small Gaussians (σ=0.05, 8 sources), GNN only

# %%
run_subcase(
    config_name='dicty_spring_force_rk4_static_field_small_gnn',
    dataset_name='dicty_spring_force_rk4_static_field_small_gnn',
    label='Case 2c: Static Small Gaussians — GNN only',
    prefix='case2c',
)
# Out:
# ============================================================
# Case 2c: Static Small Gaussians — GNN only
#   config:  dicty_spring_force_rk4_static_field_small_gnn
#   dataset: dicty_spring_force_rk4_static_field_small_gnn
# ============================================================
#   ** Data not generated yet — skipping

# %% [markdown]
# ### 2d: Small Gaussians (σ=0.05, 8 sources), GNN + SIREN

# %%
run_subcase(
    config_name='dicty_spring_force_rk4_static_field_small_siren',
    dataset_name='dicty_spring_force_rk4_static_field_small_siren',
    label='Case 2d: Static Small Gaussians — GNN + SIREN',
    prefix='case2d',
)
# Out:
# ============================================================
# Case 2d: Static Small Gaussians — GNN + SIREN
#   config:  dicty_spring_force_rk4_static_field_small_siren
#   dataset: dicty_spring_force_rk4_static_field_small_siren
# ============================================================
#   ** Data not generated yet — skipping

# %% [markdown]
# ---
# ## Case 3: Moving Gaussian field
#
# ### 3a: Big Gaussian (σ=0.15), GNN + SIREN (vector)

# %%
CFG_3A = 'dicty_spring_force_rk4_dynamic_field_siren_v4'
DAT_3A = 'dicty_spring_force_rk4_dynamic_field_siren_v4'

run_subcase(
    config_name=CFG_3A,
    dataset_name=DAT_3A,
    label='Case 3a: Moving Big Gaussian — GNN + SIREN',
    prefix='case3a',
)

print('\n--- Loss curve ---')
make_loss_curve(CFG_3A, 'case3a_loss')
# Out:
# ============================================================
# Case 3a: Moving Big Gaussian — GNN + SIREN
#   config:  dicty_spring_force_rk4_dynamic_field_siren_v4
#   dataset: dicty_spring_force_rk4_dynamic_field_siren_v4
# ============================================================
#
# --- Simulation ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   50/160
#   100/160
#   150/160
#   -> case3a_sim.mp4
#
# --- Force learning ---
#   Found 80 MLP1 plots
#   Using 40 frames
#   -> case3a_force.mp4
#
# --- Field learning ---
#   50
#   100
#   150
#   -> case3a_field.mp4
#
# --- Reconstruction ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 CFG_3A = 'dicty_spring_force_rk4_dynamic_field_siren_v4'
#       2 DAT_3A = 'dicty_spring_force_rk4_dynamic_field_siren_v4'
# ----> 4 run_subcase(
#       5     config_name=CFG_3A,
#       6     dataset_name=DAT_3A,
#       7     label='Case 3a: Moving Big Gaussian — GNN + SIREN',
#       8     prefix='case3a',
#       9 )
#      11 print('\n--- Loss curve ---')
#      12 make_loss_curve(CFG_3A, 'case3a_loss')
#
# Cell In[7], line 38, in run_subcase(config_name, dataset_name, label, prefix, has_field)
#      35     make_field_learning_video(config_name, f'{prefix}_field')
#      37 print(f'\n--- Reconstruction ---')
# ---> 38 make_reconstruction_3d(dataset_name, config_name, label, f'{prefix}_recon', n_rollout=5)
#      40 print(f'\nDone: {label}\n')
#
# Cell In[3], line 52, in make_reconstruction_3d(dataset_name, config_name, title, output_name, frame_step, fps, max_frames, n_rollout)
#      50     cur = torch.tensor(pos_all[fi], dtype=torch.float32)
#      51     for _ in range(n_rollout):
# ---> 52         vel = predict_vel(cur)
#      53         cur = (cur + vel * dt) % 1.0
#      54 pred_pos = cur.numpy()
#
# Cell In[3], line 36, in make_reconstruction_3d.<locals>.predict_vel(pos_t)
#      34 if not nbrs.any(): continue
#      35 dp = (pos_t[nbrs] - pos_t[ci]) / max_radius
# ---> 36 r = dist[ci, nbrs].unsqueeze(1) / max_radius
#      37 emb = med_emb.unsqueeze(0).expand(dp.shape[0], -1)
#      38 inp = torch.cat([dp, r, emb], dim=-1)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3b: GNN + SIREN — `dicty_spring_force_rk4_dynamic_field_siren_v6`

# %%
CFG_3B = 'dicty_spring_force_rk4_dynamic_field_siren_v6'
DAT_3B = 'dicty_spring_force_rk4_dynamic_field_siren_v6'

run_subcase(
    config_name=CFG_3B,
    dataset_name=DAT_3B,
    label='Case 3b: GNN + SIREN (v6)',
    prefix='case3b',
)

print('\n--- Loss curve ---')
make_loss_curve(CFG_3B, 'case3b_loss')
# Out:
# ============================================================
# Case 3b: GNN + SIREN (v6)
#   config:  dicty_spring_force_rk4_dynamic_field_siren_v6
#   dataset: dicty_spring_force_rk4_dynamic_field_siren_v6
# ============================================================
#
# --- Simulation ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   50/160
#   100/160
#   150/160
#   -> case3b_sim.mp4
#
# --- Force learning ---
#   Found 400 MLP1 plots
#   Using 31 frames
#   -> case3b_force.mp4
#
# --- Field learning ---
#   50
#   100
#   150
#   -> case3b_field.mp4
#
# --- Reconstruction ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   10/160
#   20/160
#   30/160
#   40/160
#   50/160
#   60/160
#   70/160
#   80/160
#   90/160
#   100/160
#   110/160
#   120/160
#   130/160
#   140/160
#   150/160
#   -> case3b_recon.mp4
#
# Done: Case 3b: GNN + SIREN (v6)
#
#
# --- Loss curve ---
#   -> case3b_loss.png

# %% [markdown]
# ### 3c: GNN + SIREN — `dicty_spring_force_rk4_dynamic_field_siren_v10`

# %%
CFG_3C = 'dicty_spring_force_rk4_dynamic_field_siren_v10'
DAT_3C = 'dicty_spring_force_rk4_dynamic_field_siren_v10'

run_subcase(
    config_name=CFG_3C,
    dataset_name=DAT_3C,
    label='Case 3c: GNN + SIREN (v10)',
    prefix='case3c',
)

print('\n--- Loss curve ---')
make_loss_curve(CFG_3C, 'case3c_loss')
# Out:
# ============================================================
# Case 3c: GNN + SIREN (v10)
#   config:  dicty_spring_force_rk4_dynamic_field_siren_v10
#   dataset: dicty_spring_force_rk4_dynamic_field_siren_v10
# ============================================================
#
# --- Simulation ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   50/160
#   100/160
#   150/160
#   -> case3c_sim.mp4
#
# --- Force learning ---
#   Found 400 MLP1 plots
#   Using 31 frames
#   -> case3c_force.mp4
#
# --- Field learning ---
#   50
#   100
#   150
#   -> case3c_field.mp4
#
# --- Reconstruction ---
#   particle radius = 0.015, scatter s = 75.9
#   0/160
#   10/160
#   20/160
#   30/160
#   40/160
#   50/160
#   60/160
#   70/160
#   80/160
#   90/160
#   100/160
#   110/160
#   120/160
#   130/160
#   140/160
#   150/160
#   -> case3c_recon.mp4
#
# Done: Case 3c: GNN + SIREN (v10)
#
#
# --- Loss curve ---
#   -> case3c_loss.png
